# %%
import seaborn as sns
# import datasets
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')

# %% [markdown]
# ## Categorical Plots
#
# ### Categorical Scatter Plot
#
# - Stripplot
# - Swarmplot
#
# ### Categorical Distribution Plots
#
# - Boxplot
# - Violinplot
#
# ### Categorical Estimate Plot -> for central tendency
#
# - Barplot
# - Pointplot
# - Countplot
#
# ### Figure level function -> `catplot`

# %%
sns.scatterplot(data=tips, x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# strip plot
# axes level function
sns.stripplot(data=tips,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#figure level func...--> catplot
sns.catplot(data=tips,x='day',y='total_bill',kind='strip')

# %%
# jitter -- > phel jata hai
sns.catplot(data=tips,x='day',y='total_bill',hue='sex',kind='strip',jitter=0.2)

# %%
# swarmplot
sns.catplot(data=tips,x='day',y='total_bill',hue='sex',kind='swarm')

#axes level fun..
#sns.swarmplot(data=tips,x='day',y='total_bill')

# %% [markdown]
# ### Boxplot
#
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile [Q1], median, third quartile [Q3] and “maximum”). It can tell you about your outliers and what their values are. Boxplots can also tell you if your data is symmetrical, how tightly your data is grouped and if and how your data is skewed.
#
# ![image.png](data:image/png;base64,...)

# %%
# categorical distribution plots

# box plot using figure level func
sns.catplot(data=tips,x='day',y='total_bill',hue='sex',kind='box')

# box plot using axes level func
#sns.boxplot(data=tips,x='day',y='total_bill')

# %%
# single boxplot -> numerical col
sns.boxplot(data=tips,y='total_bill')
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %% [markdown]
# # Violinplot = (Boxplot + KDEplot)

# %%
# Violinplot
sns.violinplot(data=tips,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips,x='day',y='total_bill',hue='sex',kind='violin')

# %%
#split=True
sns.catplot(data=tips,x='day',y='total_bill',hue='sex',kind='violin',split=True)

# %%
# barplot
# some issue with errorbar
import numpy as np
#estimator=np.min
sns.barplot(data=tips, x='sex', y='total_bill',hue='smoker',estimator=np.min)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# When there are multiple observations in each category, it also uses bootstrapping to compute a confidence interval around the estimate, which is plotted using error bars

# %%
#ci=None to remove black error bars
sns.barplot(data=tips, x='sex', y='total_bill',ci=None)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
#pointplot
sns.pointplot(data=tips, x='sex', y='total_bill',hue='smoker',ci=None)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
# countplot
sns.countplot(data=tips, x='sex',hue='day')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# faceting using catplot
sns.catplot(data=tips,x='sex',y='total_bill',col='sex',row='time',kind='box')

# %% [markdown]
# ### Regression Plots
#
# - regplot
# - lmplot
#
# In the simplest invocation, both functions draw a scatterplot of two variables, x and y, and then fit the regression model y ~ x and plot the resulting regression line and a 95% confidence interval for that regression.

# %%
#axes level function
#hue parameter not available here
sns.regplot(data=tips,x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#hue parameter available here
sns.lmplot(data=tips,x='total_bill',y='tip',hue='sex')

# %%
#residplot
sns.residplot(data=tips,x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # A second way to plot Facet plots -> FacetGrid

# %%
# figure level -> relplot -> displot -> catplot -> lmplot
#1st approach and simple -- > normally we do
sns.catplot(data=tips,x='sex',y='total_bill',kind='violin',col='day',row='time')

# %%
#2nd approach  just see don't use more often
g = sns.FacetGrid(data=tips,col='day',row='time')
g.map(sns.violinplot,'sex','total_bill')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# # Plotting Pairwise Relationship (PairGrid Vs Paiplot)

# %%
sns.pairplot(data=iris,hue='species')

# %%
#pairgrid
g = sns.PairGrid(data=tips,hue='sex')
g.map(sns.scatterplot)

# %%
# map_diag -> map_
g = sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.boxplot)
g.map_offdiag(sns.scatterplot)

# %%
# map_diag -> map_upper -> map_lower
g = sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# %%
# vars
g = sns.PairGrid(data=iris,hue='species',vars=['sepal_width','petal_width'])
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# %% [markdown]
# ### JointGrid Vs Jointplot

# %%
#1st approach
sns.jointplot(data=tips,x='total_bill',y='tip',kind='hist',hue='sex')

# %%
#2nd approach
g=sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.scatterplot,sns.boxplot)

# %% [markdown]
# # Utility Function

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# load_dataset
sns.load_dataset('planets')
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]
